# %%
import pandas as pd
import numpy as np
from hycharts import HighChart
# Out:
# /home/eddyhu/anaconda/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))
# <script src="https://code.highcharts.com/highcharts.js" />
# <script src="https://code.highcharts.com/stock/modules/exporting.js" />

# %%
as_df = pd.DataFrame(np.random.randn(1000,3),columns=['a','b','c'])

# %%
chart = HighChart.hist(as_df['a'])
chart.draw()
# Out:
#         <div id="chart_SR5S0HZ7436SIDA">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             do_chart_SR5S0HZ7436SIDA = function() {
#                 $('#chart_SR5S0HZ7436SIDA').highcharts({"yAxis": {"title": {"text": "Frequency"}}, "series": [{"colorByPoint": false, "data": [1, 8, 38, 127, 210, 250, 201, 113, 41, 11], "showInLegend": false, "tooltip": {"pointFormat": "{point.y:7.2f}"}}], "title": {"text": "Histogram"}, "chart": {"width": 600, "type": "column", "height": 400}, "plotOptions": {"column": {"pointPadding": 0, "groupPadding": 0, "borderWidth": 0}}, "xAxis": {"labels": {"format": "{value:7.2f}"}, "categories": ["  -3.60", "  -2.94", "  -2.29", "  -1.64", "  -0.98", "  -0.33", "   0.32", "   0.98", "   1.63", "   2.28", "   2.94"]}});
#             }
#             setTimeout("do_chart_SR5S0HZ7436SIDA()", 50)
#         </script>

# %%
chart = HighChart.line(as_df['a'][:30])
chart.draw()
# Out:
#         <div id="chart_5TABAW4A5O8VJ4S">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             do_chart_5TABAW4A5O8VJ4S = function() {
#                 $('#chart_5TABAW4A5O8VJ4S').highcharts({"series": [{"data": [0.060429212781769298, -0.88788334890191156, 1.1644393362876331, -0.97989919000778658, -1.4321402055884429, -0.88892938250060005, -0.33191023228742583, 0.62353048495608054, 1.2072243837494803, 0.60019076486768852, 0.45910669015999267, -0.1036242792239236, 0.56876802451227249, 0.25377037463188168, -0.63998923770169969, 1.1945237335871315, -0.81046612049201328, 1.0953262914765061, 0.64851636884257624, -0.37688878283519006, 1.121036717910104, 0.95264462865822153, -0.32100826228813184, -0.57573253882429409, 0.13687242061014554, -1.4821253547038444, 0.28780959005128504, 0.36089940404592336, 1.644630553304141, -0.27328396380857972], "name": "a"}], "yAxis": {"title": {"text": ""}}, "chart": {"width": 600, "type": "line", "height": 400}, "xAxis": {"title": {"text": ""}}, "title": {"text": "Line"}});
#             }
#             setTimeout("do_chart_5TABAW4A5O8VJ4S()", 50)
#         </script>

# %%
chart = HighChart.line(as_df[:30])
chart.draw()
# Out:
#         <div id="chart_MNBF6DUA9S97GHY">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#