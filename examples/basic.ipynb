# %%
import pandas as pd
import numpy as np
from hycharts import HighChart
# Out:
# /home/eddyhu/anaconda/lib/python2.7/site-packages/pandas/io/excel.py:626: UserWarning: Installed openpyxl is not supported at this time. Use >=1.6.1 and <2.0.0.
#   .format(openpyxl_compat.start_ver, openpyxl_compat.stop_ver))
# <script src="https://code.highcharts.com/highcharts.js" />
# <script src="https://code.highcharts.com/stock/modules/exporting.js" />

# %%
as_df = pd.DataFrame(np.random.randn(1000,3),columns=['a','b','c'])

# %%
chart = HighChart.hist(as_df['a'])
chart.draw()
# Out:
#         <div id="chart_J6DEIRQ2BH01ZN1">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             do_chart_J6DEIRQ2BH01ZN1 = function() {
#                 $('#chart_J6DEIRQ2BH01ZN1').highcharts({"yAxis": {"title": {"text": "Frequency"}}, "series": [{"colorByPoint": false, "data": [2, 12, 46, 124, 240, 228, 184, 108, 40, 16], "showInLegend": false, "tooltip": {"headerFormat": "Bin: {point.x:7.2f} </br>", "pointFormat": "Freq: {point.y:7.2f}"}}], "title": {"text": "Histogram"}, "chart": {"width": 600, "type": "column", "height": 400}, "plotOptions": {"column": {"pointPadding": 0, "groupPadding": 0, "borderWidth": 0}}, "xAxis": {"labels": {"format": "{value:7.2f}"}, "categories": ["  -3.30", "  -2.69", "  -2.08", "  -1.48", "  -0.87", "  -0.27", "   0.34", "   0.95", "   1.55", "   2.16", "   2.77"]}});
#             }
#             setTimeout("do_chart_J6DEIRQ2BH01ZN1()", 50)
#         </script>

# %%
chart = HighChart.line(as_df['a'][:30])
chart.draw()
# Out:
#         <div id="chart_ISWWQO2AS66V4AB">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             do_chart_ISWWQO2AS66V4AB = function() {
#                 $('#chart_ISWWQO2AS66V4AB').highcharts({"series": [{"data": [-0.46699275919331995, -0.4212760514170098, 1.4711526937043711, -0.56708920102916915, 0.073488457560166004, -0.76825529774702128, 1.027255464511915, -0.69095971997073102, -1.4851594433251338, 0.45407195981566467, -0.83111909708272558, 0.54841179132222451, 0.45137199181234405, 0.31617496822455826, 2.3038480994334392, 1.1955186089491485, -0.36772403268010773, 0.99872980034501924, 1.4039270362570737, -0.49073780693456132, 0.1054546437309635, -0.93438550749151772, -0.20179650989716771, 1.0350342930938072, 0.59442930212372569, 0.20773334877575578, 0.5533310259932398, 1.5879225232735379, -0.69106658611207095, 0.87710307600524207], "name": "a"}], "yAxis": {"title": {"text": ""}}, "chart": {"width": 600, "type": "line", "height": 400}, "xAxis": {"title": {"text": ""}}, "title": {"text": "Line"}});
#             }
#             setTimeout("do_chart_ISWWQO2AS66V4AB()", 50)
#         </script>

# %%
chart = HighChart.line(as_df[:30])
chart.draw()
# Out:
#         <div id="chart_4V84BK5ADV7VFTQ">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#