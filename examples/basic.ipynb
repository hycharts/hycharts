# %%
import pandas as pd
import numpy as np
from hycharts import HighChart

# %%
as_df = pd.DataFrame(np.random.randn(1000,3),columns=['a','b','c'])

# %%
chart = HighChart.hist(as_df['a'])
chart.draw()
# Out:
#         <div id="chart_H631WZ4KC0VRNZE">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             do_chart_H631WZ4KC0VRNZE = function() {
#                 $('#chart_H631WZ4KC0VRNZE').highcharts({"yAxis": {"title": {"text": "Frequency"}}, "series": [{"colorByPoint": false, "data": [5, 14, 59, 154, 261, 246, 171, 72, 13, 5], "showInLegend": false, "tooltip": {"headerFormat": "", "pointFormat": "Freq: {point.y:7.2f}"}}], "title": {"text": "Histogram"}, "chart": {"width": 600, "type": "column", "height": 400}, "plotOptions": {"column": {"pointPadding": 0, "groupPadding": 0, "borderWidth": 0}}, "xAxis": {"labels": {"format": "{value:7.2f}"}, "categories": ["  -3.40", "  -2.72", "  -2.05", "  -1.38", "  -0.70", "  -0.03", "   0.64", "   1.32", "   1.99", "   2.66", "   3.34"]}});
#             }
#             setTimeout("do_chart_H631WZ4KC0VRNZE()", 50)
#         </script>

# %%
chart = HighChart.line(as_df['a'][:30])
chart.draw()
# Out:
#         <div id="chart_YFKX53S40HD4SKM">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             do_chart_YFKX53S40HD4SKM = function() {
#                 $('#chart_YFKX53S40HD4SKM').highcharts({"yAxis": {"title": {"text": ""}}, "series": [{"data": [-0.072582560069747573, -1.2524453832461369, 1.2845731335053978, 0.0070501417084963443, -0.42717653578531145, -0.12264609147328277, -0.80030774584828779, -2.0699063688269299, 1.9679507699231431, -0.49779279086490957, -0.77548152593562891, -1.6720660418936819, -2.0048496176851178, -0.40175075834159685, 0.99390468622118278, -0.26972713951633509, -0.63193785738419916, -1.424262916317151, 0.73197475511716348, 0.18961115050084176, 1.6749008478589051, -0.60904312861918808, -0.1304280594931731, 0.62243066000285852, -1.0277462294899991, 0.7226429590998541, 0.81742374847575594, -0.76117809084028965, 1.0162600407039573, -0.36613198551642501], "name": "a"}], "title": {"text": "Line"}, "chart": {"width": 600, "zoomType": "x", "type": "line", "height": 400}, "tooltip": {"headerFormat": "<b>{series.name}</b>: ", "pointFormat": "({point.x:7.2f}, {point.y:7.2f})"}, "xAxis": {"title": {"text": ""}}});
#             }
#             setTimeout("do_chart_YFKX53S40HD4SKM()", 50)
#         </script>

# %%
chart = HighChart.line(as_df[:30])
chart.draw()
# Out:
#         <div id="chart_8189D8XGAE15LYU">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             do_chart_8189D8XGAE15LYU = function() {
#                 $('#chart_8189D8XGAE15LYU').highcharts({"yAxis": {"title": {"text": ""}}, "series": [{"data": [-0.072582560069747573, -1.2524453832461369, 1.2845731335053978, 0.0070501417084963443, -0.42717653578531145, -0.12264609147328277, -0.80030774584828779, -2.0699063688269299, 1.9679507699231431, -0.49779279086490957, -0.77548152593562891, -1.6720660418936819, -2.0048496176851178, -0.40175075834159685, 0.99390468622118278, -0.