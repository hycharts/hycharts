# %%
import pandas as pd
import numpy as np
import hycharts as hc
import hycharts.threedee as hc3

# %%
as_df = pd.DataFrame(np.random.randn(1000,3),columns=['a','b','c'])

# %%
chart = hc.hist(as_df['a'])
chart.draw()
# Out:
#         <div id="chart_BVBCFLRCOO794XW">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             make_chart_BVBCFLRCOO794XW = function() {
#                 // create HighCharts instance
#                 chart_BVBCFLRCOO794XW =  $('#chart_BVBCFLRCOO794XW').highcharts({"yAxis": {"title": {"text": "Frequency"}}, "series": [{"colorByPoint": false, "data": [12, 38, 101, 200, 234, 211, 131, 52, 12, 9], "showInLegend": false, "tooltip": {"headerFormat": "", "pointFormat": "Freq: {point.y:7.2f}"}}], "title": {"text": "Histogram"}, "chart": {"width": 600, "type": "column", "height": 400}, "plotOptions": {"column": {"pointPadding": 0, "groupPadding": 0, "borderWidth": 0}}, "xAxis": {"labels": {"format": "{value:7.2f}"}, "categories": ["  -2.77", "  -2.17", "  -1.56", "  -0.96", "  -0.35", "   0.26", "   0.86", "   1.47", "   2.07", "   2.68", "   3.28"]}});
#                 // return chart instance
#                 chart_BVBCFLRCOO794XW.highcharts();
#             }
#             $('#chart_BVBCFLRCOO794XW').ready(make_chart_BVBCFLRCOO794XW());
#         </script>

# %%
chart = hc.line(as_df['a'][:30])
chart.draw()
# Out:
#         <div id="chart_YGPNTLOOLSSDDAD">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             make_chart_YGPNTLOOLSSDDAD = function() {
#                 // create HighCharts instance
#                 chart_YGPNTLOOLSSDDAD =  $('#chart_YGPNTLOOLSSDDAD').highcharts({"yAxis": {"title": {"text": ""}}, "series": [{"data": [0.13684004581184223, 0.71800927532432857, 0.44116113405353552, 0.79196500583625107, -0.78805400318297958, -0.78867510535219865, 0.19566036884575966, 1.1871826419218634, -1.3007508506780323, 0.48955193191316582, 0.93073318812098682, 1.3492227923585318, -0.013573564392961337, 1.7358890069068118, -0.85036611194201983, -0.88376634979860624, 0.6399444780556065, -0.66356798883331891, 0.64421629934555447, 0.64215223321644299, -2.7718635685803004, 1.3963736461153875, 1.5928924063269982, -0.97550352986170907, -0.20981282776301807, -0.22807331119785285, -0.15382598126229502, 1.4383315971421069, 1.1225576083276141, 1.5496666858539507], "name": "a"}], "title": {"text": "Line"}, "chart": {"width": 600, "zoomType": "x", "type": "line", "height": 400}, "tooltip": {"headerFormat": "<b>{series.name}</b>: ", "pointFormat": "({point.x:7.2f}, {point.y:7.2f})"}, "xAxis": {"title": {"text": ""}}});
#                 // return chart instance
#                 chart_YGPNTLOOLSSDDAD.highcharts();
#             }
#             $('#chart_YGPNTLOOLSSDDAD').ready(make_chart_YGPNTLOOLSSDDAD());
#         </script>

# %%
chart = hc.line(as_df[:30])
chart.draw()
# Out:
#         <div id="chart_6CT9ZM79Y3935E7">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             make_chart_6CT9ZM79Y3935E7 = function() {
#                 // create HighCharts instance
#                 chart_6CT9ZM79Y3935E7 =  $('#chart_6CT9ZM79Y3935E7').highcharts({"yAxis": {"title": {"text": ""}}, "series": [{"data": [0.13684004581184223, 0.71800927532432857, 0.44116113405353552, 0.79196500583625107, -0.78805400318297958, -0.78867510535219865, 0.19566036884575966, 1.1871826419218634, -1.3007508506780323, 0.48955193191316582, 0.93073318812098682, 1.3492227923585318, -0.013573564392961337, 1.7358890069068118, -0.85036611194201983, -0.88376634979860624, 0.6399444780556065, -0.66356798883331891, 0.64421629934555447, 0.64215223321644299, -2.7718635685803004, 1.3963736461153875, 1.5928924063269982, -0.97550352986170907, -0.20981282776301807, -0.22807331119785285, -0.15382598126229502, 1.4383315971421069, 1.1225576083276141, 1.5496666858539507], "name": "a"}, {"data": [0.8480925198797592, 0.082263705823998681, -1.0455078160496625, 0.35427550723398821, 0.31573419927234803, 0.76079146755154592, -0.26527302528070978, -1.3484122753906764, 1.0920008018272329, 1.0695626874363906, -0.061607246139713516, -0.50558399272118915, -1.601219726160521, -1.0138309958793124, 0.5887831598900154, -1.0370989672845286, 1.1089914450710325, -1.0475966081906227, 0.57995168329438407, -0.4376211013957092, 0.240740450451289, -0.96939385785745147, -1.4130317026225474, 0.4425985348702709, 0.76810135125520418, -1.6855126991935041, -0.68744680705870109, 3.0109434071999348, 0.71833851963315798, -1.2481547328518567], "name": "b"}, {"data": [-2.5031401028443554, 0.25927786994506236, 0.86138313931193244, 0.42952705155361603, -0.21011090973527954, 1.4547556237850412, -0.095478421417537276, 0.19358050302365698, -2.0603972977438905, -0.20272792765274808, -2.7099926563515493, -0.68091675139763264, 1.3170745722744348, 0.11958919165923189, 1.3679982554693977, 1.1090560157003724, -0.077174801195810092, 0.55733886090987494, 0.065491403426328851, 0.18116150796636896, 1.6683908559274268, 0.72284601454758624, -2.1608931335959798, 1.3580881709203954, 0.35117704546411976, 0.030284127254261953, 1.6414313319289542, -0.64049858258429326, -1.0734410138735881, 1.3046535612969681], "name": "c"}], "title": {"text": "Line"}, "chart": {"width": 600, "zoomType": "x", "type": "line", "height": 400}, "tooltip": {"headerFormat": "<b>{series.name}</b>: ", "pointFormat": "({point.x:7.2f}, {point.y:7.2f})"}, "xAxis": {"title": {"text": ""}}});
#                 // return chart instance
#                 chart_6CT9ZM79Y3935E7.highcharts();
#             }
#             $('#chart_6CT9ZM79Y3935E7').ready(make_chart_6CT9ZM79Y3935E7());
#         </script>

# %%
chart = hc.scatter(as_df['a'],as_df['b'])
chart.draw()
# Out:
#         <div id="chart_6M46Y639JKU5IIR">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             make_chart_6M46Y639JKU5IIR = function() {
#                 // create HighCharts instance
#                 chart_6M46Y639JKU5IIR =  $('#chart_6M46Y639JKU5IIR').highcharts({"series": [{"colorByPoint": false, "data": [[0.13684004581184223, 0.8480925198797592], [0.71800927532432857, 0.082263705823998681], [0.44116113405353552, -1.0455078160496625], [0.79196500583625107, 0.35427550723398821], [-0.78805400318297958, 0.31573419927234803], [-0.78867510535219865, 0.76079146755154592], [0.19566036884575966, -0.26527302528070978], [1.1871826419218
# %%
as_df = pd.DataFrame(np.random.randint(low=1000,high=1000000,size=(10,4)), columns=['a','b','c','d'], index=np.arange(1990,2000))

# %%
chart = hc.area(as_df)
chart.draw()
# Out:
#         <div id="chart_5KNPODFJ1I6LD0A">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             make_chart_5KNPODFJ1I6LD0A = function() {
#                 // create HighCharts instance
#                 chart_5KNPODFJ1I6LD0A =  $('#chart_5KNPODFJ1I6LD0A').highcharts({"yAxis": {"title": {"text": "Percent"}}, "series": [{"data": [86110, 20349, 882123, 439037, 50640, 620522, 793995, 741111, 301519, 49883], "name": "a"}, {"data": [242461, 539319, 984445, 546815, 76404, 142728, 117532, 245657, 560051, 244454], "name": "b"}, {"data": [564612, 596135, 368314, 795750, 272491, 956147, 725696, 682996, 892055, 894402], "name": "c"}, {"data": [580172, 992516, 994084, 541465, 677700, 68060, 578188, 835401, 702274, 226469], "name": "d"}], "title": {"text": "Area"}, "chart": {"width": 600, "zoomType": "x", "type": "area", "height": 400}, "tooltip": {"shared": true, "pointFormat": "<span style=\"color:{series.color}\">{series.name}</span>: <b>{point.percentage:.1f}%</b> ({point.y:,.0f})<br/>"}, "plotOptions": {"area": {"stacking": "percent", "marker": {"lineWidth": 1, "lineColor": "#ffffff"}, "lineWidth": 1, "lineColor": "#ffffff"}}, "xAxis": {"categories": [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999], "title": {"text": ""}}});
#                 // return chart instance
#                 chart_5KNPODFJ1I6LD0A.highcharts();
#             }
#             $('#chart_5KNPODFJ1I6LD0A').ready(make_chart_5KNPODFJ1I6LD0A());
#         </script>

# %%
as_df = pd.DataFrame(np.random.randn(250,3),columns=['a','b','c'])
chart = hc3.scatter(as_df['a'],as_df['b'],as_df['c'], colorbypoint=True)
chart.draw()
# Out:
#         <div id="chart_IKRI15YJFUGZ87R">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             // Create chart in div when ready on page
#             $('#chart_IKRI15YJFUGZ87R').ready($('#chart_IKRI15YJFUGZ87R').highcharts({"yAxis": {"max": 2.3523952894664069, "min": -2.5202205413508167, "title": {"text": "b"}}, "series": [{"colorByPoint": true, "data": [[-0.61782380728743869, 0.14270859771669192, -0.28074420363697916], [1.6468726325708547, -0.68807344222129951, -0.81445694027140692], [-1.0612458526724229, 1.9417809756743298, -0.55482842445831737], [0.03887931491331139, 0.18967224082027789, 1.0017568644620092], [0.57413680011455992, -1.512309783595416, -1.0576951953134066], [-1.8625625256761797, 0.90244829033818408, 1.5544385083419245], [0.94308337017648169, 1.7898526259602525, 0.85216724223681473], [-0.23499799659189527, -0.22479673808220627, -0.63482291237265098], [-0.75009045872543367, 0.79844655973746392, -2.4344592