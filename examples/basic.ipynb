# %%
import pandas as pd
import numpy as np
import hycharts as hc
import hycharts.stock as hs
import hycharts.threedee as hc3
from IPython.display import display, HTML, Javascript

# %%
as_df = pd.DataFrame(np.random.randn(1000,3),columns=['a','b','c'], index=pd.date_range('1/1/2000', periods=1000, freq='d'))

# %%
chart = hs.series(as_df['a'])
chart.draw()
# Out:
#         <div id="chart_V0Y8DIY3EJYC823">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             // Create chart in div when ready on page
# ...

# %%
chart = hc.hist(as_df['a'])
chart.draw()
# Out:
#         <div id="chart_4PUJ33PTDO9RK7Q">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             // Create chart in div when ready on page
#             $('#chart_4PUJ33PTDO9RK7Q').ready($('#chart_4PUJ33PTDO9RK7Q').highcharts({"yAxis": {"title": {"text": "Frequency"}}, "series": [{"colorByPoint": false, "data": [6, 42, 80, 207, 259, 207, 130, 52, 13, 4], "showInLegend": false, "tooltip": {"headerFormat": "", "pointFormat": "Freq: {point.y:7.2f}"}}], "title": {"text": "Histogram"}, "chart": {"width": 600, "type": "column", "height": 400}, "plotOptions": {"column": {"pointPadding": 0, "groupPadding": 0, "borderWidth": 0}}, "xAxis": {"labels": {"format": "{value:7.2f}"}, "categories": ["  -3.02", "  -2.38", "  -1.75", "  -1.11", "  -0.47", "   0.17", "   0.81", "   1.45", "   2.09", "   2.72", "   3.36"]}}));
#         </script>

# %%
chart = hc.line(as_df['a'][:30])
chart.draw()
# Out:
#         <div id="chart_UFQT1Y6Q9FFO2UA">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             // Create chart in div when ready on page
# ...

# %%
chart = hc.line(as_df[:30])
chart.draw()
# Out:
#         <div id="chart_65NTT4LAQ8Q27TY">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             // Create chart in div when ready on page
# ...

# %%
chart = hc.scatter(as_df['a'],as_df['b'])
chart.draw()
# Out:
#         <div id="chart_J35OIO8KI5RQAQD">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             // Create chart in div when ready on page
# ...

# %%
as_df = pd.DataFrame(np.random.randint(low=1000,high=1000000,size=(10,4)), columns=['a','b','c','d'], index=np.arange(1990,2000))

# %%
chart = hc.area(as_df)
chart.draw()
# Out:
#         <div id="chart_6TK1HS79KMTV36K">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             // Create chart in div when ready on page
# ...

# %%
as_df = pd.DataFrame(np.random.randn(250,3),columns=['a','b','c'])
chart = hc3.scatter(as_df['a'],as_df['b'],as_df['c'], colorbypoint=True, rotation=True)
chart.draw()
# Out:
#         <div id="chart_IAC5228NWDS9RX1">
#             Re-run cell if chart is not shown ...
#         </div>
#         <script>
#             // Create chart in div when ready on page
# ...
